# %% [markdown]
# ### Training LLaMa from scratch
#
# We will train a LLaMa-based model on C# code. We want to remove all of the comments so that it only knows about code, and we can fine-tune this model for Q&A and instruction, amongst other things.

# %% [markdown]
# We will use the microsoft/LCC_csharp dataset from 🤗 Datasets.
# We first need to remove all the comments from the code, and then we need to string all of the training data together so that it can all be fed into the tokenizer.

# %%
# %pip install Datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datasets

dataset = datasets.load_dataset("microsoft/LCC_csharp")
small_training_dataset = dataset["train"].shuffle(42).select(range(1))

# %%
small_training_dataset[0]["context"].replace()
# Out:
# '// Copyright (c) The Avalonia Project. All rights reserved.\n// Licensed under the MIT license. See licence.md file in the project root for full license information.\n\nusing Avalonia.Media;\nusing Avalonia.Platform;\nusing SkiaSharp;\nusing System;\nusing System.Collections.Generic;\nusing System.Linq;\n\nnamespace Avalonia.Skia\n{\n    public class FormattedTextImpl : IFormattedTextImpl\n    {\n        public FormattedTextImpl(string text, string fontFamilyName, double fontSize, FontStyle fontStyle,\n                    TextAlignment textAlignment, FontWeight fontWeight, TextWrapping wrapping)\n        {\n            _text = text ?? string.Empty;\n\n            // Replace 0 characters with zero-width spaces (200B)\n            _text = _text.Replace((char)0, (char)0x200B);\n\n            var typeface = TypefaceCache.GetTypeface(fontFamilyName, fontStyle, fontWeight);\n\n            _paint = new SKPaint();\n\n            //currently Skia does not measure properly with Utf8 !!!\n    
# ...
